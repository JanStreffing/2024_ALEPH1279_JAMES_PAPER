# %%
import pyfesom2 as pf
import matplotlib.cm as cm
import xarray as xr
import cmocean as cmo
import numpy as np
# Out:
# osgeo is not installed, conversion to Geo formats like Geotiff (fesom2GeoFormat) will not work.

# %%
# set the path to the mesh
mesh_name = 'LR'

if mesh_name == 'LR':
    meshpath  ='/p/project/chhb19/jstreffi/input/fesom2/core2/'
    area_file ='/p/project/chhb19/jstreffi/input/fesom2/core2/CORE2_finaltopo_mean.nc'
    alpha, beta, gamma=[0, 0, 0]
    mesh_n_points = 126858
elif mesh_name == 'MR':
    meshpath  ='/work/ollie/jstreffi/input/fesom2/MR/'
    alpha, beta, gamma=[0, 0, 0]
    mesh_n_points = 830305
elif mesh_name == 'HR':
    meshpath  ='/work/ollie/jstreffi/input/fesom2/HR/'
    alpha, beta, gamma=[0, 0, 0]
    mesh_n_points = 1306775

mesh = pf.load_mesh(meshpath)  
mesh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      15     alpha, beta, gamma=[0, 0, 0]
#      16     mesh_n_points = 1306775
# ---> 18 mesh = pf.load_mesh(meshpath)
#      19 mesh
#
# NameError: name 'pf' is not defined

# %%
data_path = '/p/scratch/chhb19/jstreffi/runtime/awicm-3.1/PIC4/outdata/fesom/'
data = pf.get_data(data_path, "sst", 2200, mesh, how="mean", compute=True, depth=0)
# %%time
pf.tplot(mesh, data, ptype='tri', box=[135, 140, -36, -30], mapproj='merc')
# Out:
# Model depth: 0.0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_18283/3346277205.py in <module>
#       1 data_path = '/p/scratch/chhb19/jstreffi/runtime/awicm-3.1/PIC4/outdata/fesom/'
# ----> 2 data = pf.get_data(data_path, "sst", 2200, mesh, how="mean", compute=True, depth=0)
#       3 get_ipython().run_line_magic('%time', '')
#       4 pf.tplot(mesh, data, ptype='tri', box=[135, 140, -36, -30], mapproj='merc')
#
# /p/project/chhb19/jstreffi/software/pyfesom2/pyfesom2/load_mesh_data.py in get_data(result_path, variable, years, mesh, runid, records, depth, how, ncfile, compute, continuous, silent, transpose, **kwargs)
#     522             print("Depth is None, 3d field will be returned")
#     523
# --> 524     dataset = xr.open_mfdataset(paths, combine="by_coords", **kwargs)
#     525     data = select_slices(dataset, variable, mesh, records, depth)
# ...

# %%
mesh = pf.load_mesh('/p/project/chhb19/streffing1/input/fesom2/core2/')
data = xr.open_dataset('/p/project/chhb19/streffing1/input/fesom2/core2/fesom.mesh.diag.nc')
nod_area = data['nod_area'][0,:].values
nod_area = (np.sqrt(nod_area/np.pi)/1e3)*2
im=pf.plot(mesh, nod_area, levels = (20, 120, 11), cmap=cmo.cm.thermal_r)
# Out:
# /p/project/chhb19/streffing1/input/fesom2/core2/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /p/project/chhb19/streffing1/input/fesom2/core2/pickle_mesh_py3_fesom2

# %%
mesh = pf.load_mesh('/p/project/chhb19/streffing1/input/fesom2/dart/')
data = xr.open_dataset('/p/project/chhb19/streffing1/input/fesom2/dart/fesom.mesh.diag.nc')
nod_area = data['nod_area'][0,:].values
nod_area = (np.sqrt(nod_area/np.pi)/1e3)*2
pf.plot(mesh, nod_area, levels = (4, 28, 13), cmap=cmo.cm.thermal_r)
# Out:
# /p/project/chhb19/streffing1/input/fesom2/dart/pickle_mesh_py3_fesom2
# The usepickle == True)
# The pickle file for FESOM2 exists.
# The mesh will be loaded from /p/project/chhb19/streffing1/input/fesom2/dart/pickle_mesh_py3_fesom2
# [<GeoAxesSubplot:>]
